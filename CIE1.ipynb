# %% [markdown]
# <a href="https://colab.research.google.com/github/MahammadHafeezJamadar/AI-ML/blob/main/CIE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

iris = pd.read_csv('/content/Iris.csv',names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
# print(iris.tail())
# print(iris.head())
iris.describe()
# Out:
#        sepal_length sepal_width petal_length petal_width        class
# count           151         151          151         151          151
# unique           36          24           44          23            4
# top             5.0         3.0          1.5         0.2  Iris-setosa
# freq             10          26           14          28           50

# %%
import matplotlib.pyplot as plt
x=iris['petal_length']
y=iris['petal_width']
plt.scatter(x,y)
plt.title("Scatter plot Petal length vs width")
plt.grid(True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
# scatter the sepal_length against the sepal_width
ax.scatter(iris['sepal_length'], iris['sepal_width'])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
"""How many flowers belong to each species?"""


species_counts = iris['class'].value_counts()

plt.bar(species_counts.index, species_counts.values, color='lightblue')
plt.title("Number of Flowers by Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.grid(axis='y')

# %%
"""What is the distribution of petal length?"""
import matplotlib.pyplot as plt
plt.hist(iris['petal_length'], bins=10, color='lightgreen', edgecolor='black')
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3898807980.py in <cell line: 0>()
#       1 """What is the distribution of petal length?"""
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.hist(iris['petal_length'], bins=10, color='lightgreen', edgecolor='black')
#       4 plt.title("Distribution of Petal Length")
#       5 plt.xlabel("Petal Length (cm)")
#
# NameError: name 'iris' is not defined

# %%
"""Compare petal length between species."""


species = iris['class'].unique()
data = [iris[iris['class'] == s]['petal_length'] for s in species]

plt.boxplot(data, labels=species)
plt.title("Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-2797835456.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=species)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2797835456.py in <cell line: 0>()
#       5 data = [iris[iris['class'] == s]['petal_length'] for s in species]
#       6
# ----> 7 plt.boxplot(data, labels=species)
#       8 plt.title("Petal Length by Species")
#       9 plt.xlabel("Species")
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     293                 f"for the old name will be dropped in %(removal)s.")
#     294             kwargs[new] = kwargs.pop(old)
# --> 295         return func(*args, **kwargs)
#     296
#     297     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label, data)
#    3075     data=None,
#    3076 ) -> dict[str, Any]:
# -> 3077     return gca().boxplot(
#    3078         x,
#    3079         notch=notch,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     293                 f"for the old name will be dropped in %(removal)s.")
#     294             kwargs[new] = kwargs.pop(old)
# --> 295         return func(*args, **kwargs)
#     296
#     297     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4108             bootstrap = mpl.rcParams['boxplot.bootstrap']
#    4109
# -> 4110         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    4111                                        labels=tick_labels, autorange=autorange)
#    4112         if notch is None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/cbook.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1240
#    1241         # arithmetic mean
# -> 1242         stats['mean'] = np.mean(x)
#    1243
#    1244         # medians and quartiles
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3594             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3595
# -> 3596     return _methods._mean(a, axis=axis, dtype=dtype,
#    3597                           out=out, **kwargs)
#    3598
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     138             ret = ret.dtype.type(ret / rcount)
#     139     else:
# --> 140         ret = ret / rcount
#     141
#     142     return ret
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
"""What is the relationship between petal length and petal width?"""

plt.scatter(iris['petal_length'], iris['petal_width'], color='purple', alpha=0.6)
plt.title("Petal Length vs Petal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.show()
