# %% [markdown]
# <a href="https://colab.research.google.com/github/MahammadHafeezJamadar/AI-ML/blob/main/SEE23CS021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.hist(df['petal_length'],bins=20,color = "blue")
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length")
plt.show()

# %%
plt.scatter(df['petal_length'],df['petal_width'])
plt.title("Relationship between Petal_length and Petal_width(in CM)")
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.grid(axis=1)
plt.show()

# %%
counts = df["species"].value_counts()


plt.bar(counts.index, counts.values)

plt.title("Number of Flowers per Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %%
sns.boxplot(x="species", y="petal_length", data=iris)
plt.title("Boxplot of Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length")
plt.show()
